# %%
import matplotlib.pyplot as plt

# %%
# Data
alpha_values = [0.05, 0.10, 0.15, 0.20, 0.25, 0.30, 0.35, 0.40, 0.45, 0.50, 0.55, 0.60, 0.65, 0.70, 0.75, 0.80, 0.85, 0.90, 0.95]

# V1 Data
HOTA_a_values_V1 = [0.9242, 0.9241, 0.9241, 0.9239, 0.9238, 0.9236, 0.9235, 0.9233, 0.9229, 0.9214, 0.9191, 0.9128, 0.8893, 0.8551, 0.8095, 0.6737, 0.4381, 0.3494, 0.2228]

# V2 Data (provided in the previous question)
HOTA_a_values_V2 = [0.8176, 0.8174, 0.8173, 0.8171, 0.8168, 0.8165, 0.8152, 0.8051, 0.7819, 0.7632, 0.7386, 0.7052, 0.6604, 0.6055, 0.5362, 0.4452, 0.3283, 0.2871, 0.1983]

# V3 Data
HOTA_a_values_V3 = [0.7522, 0.7516, 0.7503, 0.7494, 0.7481, 0.7462, 0.7442, 0.7431, 0.7410, 0.7348, 0.7246, 0.6739, 0.6182, 0.5577, 0.4930, 0.4167, 0.2804, 0.0774, 0.0011]

# Plotting the data
plt.plot(alpha_values, HOTA_a_values_V1, label='V1', linestyle='-', color='r')
plt.plot(alpha_values, HOTA_a_values_V2, label='V2', linestyle='-', color='b')
plt.plot(alpha_values, HOTA_a_values_V3, label='V3', linestyle='-', color='g')

# Adding labels and legend
plt.title('Representation of HOTA$_{\\alpha}$ values with respect to $\\alpha$')
plt.xlabel('$\\alpha$')
plt.ylabel('HOTA$_{\\alpha}$')
plt.legend()
plt.grid(True)
plt.show()
